# %%
import pandas as pd

# %%
df = pd.read_parquet('config.data')
df
# Out:
#      map_text                               map    team1   team2   score  \
# 0  de_ancient  ./app/static/maps/de_ancient.png  Hungary  Norway  5 - 13
# 2  de_vertigo  ./app/static/maps/de_vertigo.png  Hungary  Norway  7 - 13
#
#           source match_page                               file_id  \
# 0  manual upload       ----  b586e7ff-caab-464d-b54c-aea2c9076834
# 2  manual upload       ----  8a28dfe1-2be1-4064-867f-6b14aae282aa
#
#   include/exclude/delete
# 0                Exclude
# 2                Include

# %%
df = pd.read_parquet('rounds.data')
df
# Out:
#     round   start  freeze_end     end  official_end winner         reason  \
# 0       1      91        1787    5825          6273      T      ct_killed
# 1       2    6273        7553    8870          9318      T      ct_killed
# 2       3    9318       10598   15358         15806      T      ct_killed
# 3       4   15806       17086   21946         22394     CT       t_killed
# 4       5   22394       23674   28404         28852      T  bomb_exploded
# 5       6   28852       30132   34952         35400      T      ct_killed
# 6       7   35400       36680   41595         42043      T  bomb_exploded
# 7       8   42043       45670   49900         50348     CT       t_killed
# 8       9   50348       51628   55601         56049      T      ct_killed
# 9      10   56049       57329   61069         61517      T      ct_killed
# 10     11   61517       65046   69074         69522     CT       t_killed
# 11     12   69522       70802   75407         75951      T      ct_killed
# ...
